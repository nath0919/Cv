# %% [markdown]
# # Nathael Ramos Cabrera
#
# Ciudad de México, México
#
# WhatsApp +52 5564924974 | tel. +52 5562339839
#
# [racanat8@gmail.com](mailto:racanat8@gmail.com)
#
# [LinkedIn](https://www.linkedin.com/in/nathael-ramos-7b2791177/)
#
# [GitHub](https://github.com/nath0919)
#
# [Hugging Face](https://huggingface.co/naraca)
#
# ---
#
# ## Perfil profesional
# Soy una persona autodidacta, disciplinada y apasionada por resolver problemas
# difíciles, especialmente aquellos que permiten descubrir cómo funciona algo
# desde dentro. Me especializo en la intersección entre matemáticas, aprendizaje
# automático e interpretabilidad de modelos. Actualmente desarrollo un proyecto
# enfocado en el análisis mecanicista de Transformers y he replicado
# experimentalmente ChatGPT-2 como parte de mi formación autodirigida. Domino
# Python, Numpy, Pandas, PyTorch, TensorFlow y herramientas avanzadas como Hydra. Mi objetivo
# es integrarme a empresas tecnológicas de alto impacto como Meta, Google o
# Amazon, contribuyendo con soluciones claras, útiles y explicables.
#
# ---
#
# ## Educación
# | Años | Grado / Institución | Ciudad |
# |------|---------------------|--------|
# | 2021–2025 | **Lic. Matemáticas** – Universidad Autónoma Metropolitana | CDMX |
#
# ---
#
# ## Certificaciones y Reconocimientos
# * 2024 – Curso de Python para Ciencia de Datos – Google / Coursera
# * 2024 – Reconocimiento por haber impartido el taller Python desde 0 – UAM
# * 2024 – Reconocimiento por haber impartido el taller Python y ChatGPT – UAM
# * 2024 - Reconocimiento por haber impartido el taller de Python con inteligencia
#   artificial - UAM
# ---
#
# ## Habilidades Técnicas
#
# -  Python (uso fluido con y sin ejemplos)
# -  R (estadística bayesiana)
# -  Markdown/LaTeX (redacción matemática profesional)
# -  Git + GitHub (branches, pull requests, proyectos propios)
# -  Hugging Face (manejo de datasets/modelos)
# -  VS Code (editor principal), Google Colab (secundario)
# -  Álgebra lineal, cálculo multivariable, análisis real y complejo
# -  Estadística bayesiana aplicada
#
#
# ---
#
# ## Idiomas
# | Idioma  | Nivel |
# |---------|-------|
# | Español | Nativo |
# | Inglés  | Intermedio (B1–B2) |
#
# ---
#
# ## Proyectos Relevantes
#
# 1. **Interpretabilidad mecanicista de Transformers (2025 – en curso)**
#    Proyecto final universitario centrado en el análisis interno de modelos Transformer mediante extracción de activaciones y entrenamiento de autoencoders dispersos. Basado en la metodología de GemmaScope.
#    Incluye implementación matemática desde cero, documentación rigurosa y experimentación con representaciones internas de LLaMA 3.2.
#
# 2. **Recreación y experimentación con ChatGPT-2 (2024)**
#    Implementación y entrenamiento autodidacta de un modelo GPT-2 desde cero.
#    Incluye ajustes manuales, análisis de arquitectura, comprensión funcional de capas de atención y generación de texto bajo diversas condiciones experimentales.
#
# 3. **Script de extracción de activaciones MLP8 para LLaMA 3.2 (2025)**
#    Desarrollo de un pipeline completo para extraer y empaquetar activaciones neuronales desde LLaMA 3.2.
#    Automatización del procesamiento por lotes, compresión eficiente y carga continua a Hugging Face (`naraca/mi-dataset-activaciones-llama3_2`).
#
# 4. **Modelo Bayesiano de tasas de nacimientos (2025)**
#    Comparación de modelos estadísticos mediante el Factor de Bayes aplicado a datos hospitalarios.
#    Implementado en R usando métodos jerárquicos y verificación posterior.
#
# 5. **Servicio social en aprendizaje no supervisado (2025 – planeado)**
#    Desarrollo de un sistema basado en representaciones latentes no supervisadas tipo DeepSpeak, orientado a tareas de clasificación y reducción de dimensionalidad para lenguaje natural.
#
# ---
#
# *Última actualización: {{2 de julio 2025}}*
